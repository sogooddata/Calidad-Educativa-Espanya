# %% [markdown]
# # Example generated from http://varianceexplained.org/r/kmeans-free-lunch
#
# **Este ejemplo está focalizado en subrayar el denominado como  "No Free Lunch Theorem": http://ti.arc.nasa.gov/m/profile/dhw/papers/78.pdf
# **
#
# **“When averaged across all possible situations, every algorithm performs equally well.”**
#
# Para tratar de tener una idea sobre las implicaciones de dicho teorema, ejecutaremos el código que figura a continuación varias veces.

# %% [markdown]
# En primer lugar importamos las bibliotecas que necesitaremos en esta práctica

# %%
import random 
# %matplotlib inline
import matplotlib.pyplot as plt
import math
import numpy as np

# %% [markdown]
# Generamos dos poblaciones gausianas con distribuciones concéntricas.

# %%
x = []
y = []
x1 = []
y1 = []
for i in range(1,551):
    aux = random.gauss(0,1)
    x.append(aux)
    aux = random.gauss(0,1)
    y.append(aux)
    #para la segunda población hacemos que las muestras se distribuyan
    #en el entorno de la circunferencia de radio 5 (de acuerdo con una distribucion gausiana)
    r = random.gauss(5,0.25)
    #Los puntos aleatorios son generados de acuerdo con una representación polar 
    #p=(r*cos(angulo),r*sin(angulo)). r se escoge a partir de una distribución gausiana de media 
    #5 y varianza 0.25. El ángulo, por su parte, se genera aleatoriamente según un distribución
    #uniforme en [0,2pi]
    theta = random.uniform(0,2*math.pi)
    x1.append(r*math.cos(theta))
    y1.append(r*math.sin(theta))

# %%
plt.plot(x,y,'ro')
plt.plot(x1,y1,'bo')
plt.show()

# %% [markdown]
# Vamos a intentar identificar las dos clases que tenemos empleando kmeans. Para ello, importamos las bibliotecas necesarias e inicializamos la clase Kmeans de scikitlearn. Como podéis comprobar, hemos escogido k=2 y el proceso de inicialización de centroides se hará de modo aleatorio.

# %%
from sklearn import metrics
from sklearn.cluster import KMeans

# %%
km = KMeans(n_clusters=2,init='random',n_init=1,verbose=1)

# %% [markdown]
# A continuación convertimos a array el par de listas con las que hemos trabajado hasta este punto.

# %%
x = np.array(x)

# %%
y = np.array(y)

# %%
data = np.vstack((x,y)).T

# %%
x1 = np.array(x1)
y1 = np.array(y1)
data1 = np.vstack((x1,y1)).T
data1 = np.concatenate((data,data1))

# %%
data1.shape
# Out:
# (1100, 2)

# %%
x.shape
# Out:
# (550,)

# %% [markdown]
# Representamos la columna 1 respecto a la 0.

# %%
plt.plot(data1[:,0],data1[:,1],'.')
plt.show()

# %%
km.fit(data1)
# Out:
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 11291.111512631986
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 11034.866195658191
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 10925.454318655564
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 10882.08595454271
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 10857.121769490012
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 10846.72408908587
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 10836.19235215516
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 10827.074457200386
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 10817.296766905523
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 10807.663617681023
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 10794.384710289096
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 10777.91763827832
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 10755.762962849141
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 10733.874480977205
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 10704.984240972877
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 10678.018665816368
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 10657.260549158216
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 10640.661313270193
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 10626.012756785705
# start iteration
# done sorting
# end inner loop
# Iteration 19, inertia 10616.038196872323
# start iteration
# done sorting
# end inner loop
# Iteration 20, inertia 10606.413950307104
# start iteration
# done sorting
# end inner loop
# Iteration 21, inertia 10601.064380938966
# start iteration
# done sorting
# end inner loop
# Iteration 22, inertia 10598.226061843267
# start iteration
# done sorting
# end inner loop
# Iteration 23, inertia 10588.551644055378
# start iteration
# done sorting
# end inner loop
# Iteration 24, inertia 10570.610819927977
# start iteration
# done sorting
# end inner loop
# Iteration 25, inertia 10546.197416076917
# start iteration
# done sorting
# end inner loop
# Iteration 26, inertia 10538.793853167055
# start iteration
# done sorting
# end inner loop
# Iteration 27, inertia 10531.445399992554
# start iteration
# done sorting
# end inner loop
# Iteration 28, inertia 10516.976552417045
# start iteration
# done sorting
# end inner loop
# Iteration 29, inertia 10510.074322369503
# start iteration
# done sorting
# end inner loop
# Iteration 30, inertia 10508.009201735933
# start iteration
# done sorting
# end inner loop
# Iteration 31, inertia 10505.359251676968
# start iteration
# done sorting
# end inner loop
# Iteration 32, inertia 10502.4918684141
# start iteration
# done sorting
# end inner loop
# Iteration 33, inertia 10498.112033814135
# start iteration
# done sorting
# end inner loop
# Iteration 34, inertia 10492.153995118646
# start iteration
# done sorting
# end inner loop
# Iteration 35, inertia 10484.816527180068
# start iteration
# done sorting
# end inner loop
# Iteration 36, inertia 10471.906237584062
# start iteration
# done sorting
# end inner loop
# Iteration 37, inertia 10468.974189111836
# start iteration
# done sorting
# end inner loop
# Iteration 38, inertia 10466.109900667372
# start iteration
# done sorting
# end inner loop
# Iteration 39, inertia 10461.680209827979
# start iteration
# done sorting
# end inner loop
# Iteration 40, inertia 10448.90861428894
# start iteration
# done sorting
# end inner loop
# Iteration 41, inertia 10441.769335708452
# start iteration
# done sorting
# end inner loop
# Iteration 42, inertia 10432.8616675436
# start iteration
# done sorting
# end inner loop
# Iteration 43, inertia 10420.891255340071
# start iteration
# done sorting
# end inner loop
# Iteration 44, inertia 10415.916794588364
# start iteration
# done sorting
# end inner loop
# Iteration 45, inertia 10410.288454063571
# start iteration
# done sorting
# end inner loop
# Iteration 46, inertia 10404.052166460018
# start iteration
# done sorting
# end inner loop
# Iteration 47, inertia 10397.558111383041
# start iteration
# done sorting
# end inner loop
# Iteration 48, inertia 10391.59672766186
# start iteration
# done sorting
# end inner loop
# Iteration 49, inertia 10387.260460280544
# start iteration
# done sorting
# end inner loop
# Iteration 50, inertia 10383.936689315458
# start iteration
# done sorting
# end inner loop
# Iteration 51, inertia 10382.69950745873
# start iteration
# done sorting
# end inner loop
# Iteration 52, inertia 10382.02448704808
# start iteration
# done sorting
# end inner loop
# Iteration 53, inertia 10381.208733609852
# start iteration
# done sorting
# end inner loop
# Iteration 54, inertia 10380.411766693076
# start iteration
# done sorting
# end inner loop
# Iteration 55, inertia 10379.48682235457
# start iteration
# done sorting
# end inner loop
# Iteration 56, inertia 10378.756529240543
# start iteration
# done sorting
# end inner loop
# Iteration 57, inertia 10378.640460224407
# center shift 1.017825e-02 within tolerance 6.797750e-04
# KMeans(algorithm='auto', copy_x=True, init='random', max_iter=300, n_clusters=2,
#        n_init=1, n_jobs=None, precompute_distances='auto', random_state=None,
#        tol=0.0001, verbose=1)

# %%
km.cluster_centers_
# Out:
# array([[-2.07042341,  1.15648951],
#        [ 1.61866341, -0.64722286]])

# %%
km.labels_
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %%
km.labels_.shape
# Out:
# (1100,)

# %%
plt.scatter(km.cluster_centers_[:,0],km.cluster_centers_[:,1],marker='x',s=169,linewidths=3,color='g',zorder=10)
plt.scatter(data1[:,0],data1[:,1])
unique_labels = set(km.labels_)
colors = plt.cm.Spectral(np.linspace(0,1,len(unique_labels)))
xy = data1[km.labels_==0]
plt.scatter(xy[:,0],xy[:,1],color='r')
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
single_link = AgglomerativeClustering(linkage='ward',n_clusters=2)

# %%
h_clusters = single_link.fit(data1)

# %%
plt.scatter(data1[h_clusters.labels_==0,0],data1[h_clusters.labels_==0,1],color='blue')
plt.scatter(data1[h_clusters.labels_==1,0],data1[h_clusters.labels_==1,1],color='red')

# %%
from sklearn.neighbors import kneighbors_graph
connectivity = kneighbors_graph(data1, n_neighbors=30, include_self=False)

# %%
single_link2 = AgglomerativeClustering(linkage="ward",n_clusters=2,connectivity=connectivity)

# %%
h_clusters2 = single_link2.fit(data1)

# %%
plt.scatter(data1[h_clusters2.labels_==0,0],data1[h_clusters2.labels_==0,1],color='blue')
plt.scatter(data1[h_clusters2.labels_==1,0],data1[h_clusters2.labels_==1,1],color='red')

# %%
connectivity = kneighbors_graph(data1, n_neighbors=10, include_self=False)

for index, metric in enumerate(["cosine", "euclidean", "cityblock"]):
    model = AgglomerativeClustering(n_clusters=2,
                                    linkage="complete", affinity=metric,connectivity=connectivity)
    model.fit(data1)
    plt.figure()
    
    for l, c in zip(np.arange(model.n_clusters), 'rg'):
        plt.scatter(data1[model.labels_ == l,0],data1[model.labels_ == l,1], c=c, alpha=.5)
    plt.axis('tight')
    plt.axis('off')
    plt.suptitle("AgglomerativeClustering(affinity=%s)" % metric, size=20)

# %% [markdown]
# # Vamos a probar otra manera de análisis. Para ello, vamos a expresar los puntos con notación polar.

# %%
r = np.sqrt(data1[:,0]**2+data1[:,1]**2)

# %%
theta = np.arctan(data1[:,1]/data1[:,0])

# %%
data2 = np.column_stack((r,theta))

# %%
data2.shape
# Out:
# (1100, 2)

# %%
km.fit(data2)
# Out:
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 1164.499754139095
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 1163.1547608532226
# center shift 1.406473e-02 within tolerance 2.286136e-04
# KMeans(algorithm='auto', copy_x=True, init='random', max_iter=300, n_clusters=2,
#        n_init=1, n_jobs=None, precompute_distances='auto', random_state=None,
#        tol=0.0001, verbose=1)

# %%
plt.scatter(data2[km.labels_==0,0],data2[km.labels_==0,1],color='r',alpha=0.5)
plt.scatter(data2[km.labels_==1,0],data2[km.labels_==1,1],color='b',alpha=0.5)
plt.scatter(km.cluster_centers_[:,0],km.cluster_centers_[:,1],marker='x',s=169,linewidths=3,color='g',zorder=10)

# %% [markdown]
# # Otro problema de kmeans viene derivado de la existencia de poblaciones con tamaños muy distinto. En el ejemplo tenemos poblaciones con distinto tamaño.

# %%
sizes = np.array([10,100,1000])

# %% [markdown]
# ** Arriba hemos definido el tamaño de las tres poblaciones. A continuación se definen la media de cada población en cada uno de los ejes. **

# %%
avgs_x = np.array([1,4,10])
avgs_y = np.array([5,0,10])

# %%
import time

seed = time.time()
data3 = np.zeros(1);

for a_x,a_y,s in zip(avgs_x,avgs_y,sizes):
    cx = []
    cy = []
    for  i in range(s):
        cx.append(random.gauss(a_x,1))
        cy.append(random.gauss(a_y,1))
    cx = np.array(cx)
    cy = np.array(cy)
    aux = np.vstack((cx,cy)).T
    
    if data3.shape[0] == 1:
        data3 = aux
    else:
        data3 = np.concatenate((data3,aux))
        
data3.shape
# Out:
# (1110, 2)

# %%
plt.plot(data3[:,0],data3[:,1],'ko',alpha=0.3)

# %%
km = KMeans(n_clusters=3,init='random',n_init=1,verbose=1)

# %%
km.fit(data3)
km.cluster_centers_.shape
# Out:
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 5505.666456143292
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 1892.8205592850964
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 1892.8044766378537
# center shift 3.230942e-03 within tolerance 6.988064e-04
# (3, 2)

# %%
plt.scatter(km.cluster_centers_[:,0],km.cluster_centers_[:,1],marker='x',s=169,linewidths=3,color='g',zorder=10)
plt.scatter(data3[km.labels_==0,0],data3[km.labels_==0,1],color='r',alpha=0.5)
plt.scatter(data3[km.labels_==1,0],data3[km.labels_==1,1],color='b',alpha=0.5)
plt.scatter(data3[km.labels_==2,0],data3[km.labels_==2,1],color='k',alpha=0.5)
plt.show()

# %% [markdown]
# En muchos casos la población con más muestras tiene asociadas dos clases, mientras que las otras dos clases son fusionadas en un único cluster.

# %% [markdown]
# # Vamos a usar GMM para ver si somos capaces de solucionar algunos de los problemas que hemos destacado

# %%
from sklearn import mixture
import itertools
from scipy import linalg
import matplotlib as mpl

# %%
lowest_bic = np.infty
bic = []
n_components_range = range(1, 7)
cv_types = ['spherical', 'tied', 'diag', 'full']
for cv_type in cv_types:
    for n_components in n_components_range:
        # Fit a mixture of Gaussians with EM
        gmm = mixture.GaussianMixture(n_components=n_components, covariance_type=cv_type)
        gmm.fit(data1)
        bic.append(gmm.bic(data1))
        if bic[-1] < lowest_bic:
            lowest_bic = bic[-1]
            best_gmm = gmm

# %%
bic = np.array(bic)
color_iter = itertools.cycle(['k', 'r', 'g', 'b', 'c', 'm', 'y'])
clf = best_gmm
bars = []

# Plot the BIC scores

for i, (cv_type, color) in enumerate(zip(cv_types, color_iter)):
    xpos = np.array(n_components_range) + .2 * (i - 2)
    bars.append(plt.bar(xpos, bic[i * len(n_components_range):
                                  (i + 1) * len(n_components_range)],
                        width=.2, color=color))
plt.xticks(n_components_range)
plt.ylim([bic.min() * 1.01 - .01 * bic.max(), bic.max()])
plt.title('BIC score per model')
xpos = np.mod(bic.argmin(), len(n_components_range)) + .65 +\
    .2 * np.floor(bic.argmin() / len(n_components_range))
plt.text(xpos, bic.min() * 0.97 + .03 * bic.max(), '*', fontsize=14)
plt.xlabel('Number of components')
plt.legend([b[0] for b in bars], cv_types)

# %%
# Plot the winner
splot = plt.subplot(1, 1, 1)
Y_ = clf.predict(data1)
for i, (mean, covar, color) in enumerate(zip(clf.means_, clf.covariances_,
                                             color_iter)):
    #we are computing the eigenvalues of the covariance matrix: v is the sector of eigenvectors; 
    #w is the set of eigenvalues
    v, w = linalg.eigh(covar)
    
    if not np.any(Y_ == i):
        continue
    plt.scatter(data1[Y_ == i, 0], data1[Y_ == i, 1], .8, color=color)

    # Plot an ellipse to show the Gaussian component
    angle = np.arctan2(w[0][1], w[0][0])
    angle = 180 * angle / np.pi  # convert to degrees
    v *= 4
    ell = mpl.patches.Ellipse(mean, v[0], v[1], 180 + angle, color=color)
    ell.set_clip_box(splot.bbox)
    ell.set_alpha(.5)
    splot.add_artist(ell)

# %% [markdown]
# ## Ejercicio 2
# # Repetir el conjunto de pruebas anterior  y comentar los resultados obtenidos. Habrá que entregar un notebook a modo de informe. En el informe se explicarán:
#
# **1.-** La diferencia en los resultados al aplicar k-means con una inicialización aleatoria frente a una inicialización basada en kmeans++·
#
# **2.-** Las limitaciones al aplicar k-means a los datasets considerados.
#
# **3.-** Aplicación a los datasets de las técnicas de clustering jerárquico utilizadas en este ejemplo. Comparar los resultados con los obtenidos para kmeans.
#
# **4.-** Resultados obtenidos al aplicar GMM a los datasets considerados.
#
# **5.-** Aplicar DBSCAN a los datasets considerados y comentar los resultados obtenidos.
